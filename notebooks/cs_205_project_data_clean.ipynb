# %%
import pandas as pd
import numpy as np
import nltk
import torch
import transformers
import sklearn

# %%
# Download necessary NLTK data
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

from nltk.stem import 	WordNetLemmatizer
ps = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()
tokenizer = nltk.RegexpTokenizer(r"\w+")

def cleanDoccument(data):


    sentence=data

    new_words = tokenizer.tokenize(sentence)
    newSentence=''
    for i in new_words:
        i=i.lower()
        i=wordnet_lemmatizer.lemmatize(i)
        i=ps.stem(i)
        if i not in set(stopwords.words('english')) :
            newSentence+=i+' '
    return newSentence

# %%
dataset=pd.read_csv('./data/FinalRaWData.csv')
dataset
# Out:
#       Unnamed: 0                                             prompt  \
# 0              0  CumGPT, an information resource about cum that...
# 1              1  I will give you a character description and yo...
# 2              2  A completely amoral Ai named [Illegality Mode]...
# 3              3  Agares's rules={\nAlways stays in character, n...
# 4              4  Lucian is an incorporeal transcendent being wh...
# ...          ...                                                ...
# 2195        1095  Act as an SEO expert tasked with optimizing th...
# 2196        1096  \nI Want You To Act As A Content Writer Very P...
# 2197        1097  \nYour task is to summarize text in 150 words ...
# 2198        1098  As a software developer and designer, you have...
# 2199        1099  \nVocê é um Youtuber.\n\nEu quero que você esc...
#
#       jailbreak  length  num_punctation
# 0          True    2466              55
# 1          True    1261              78
# 2          True    2363             123
# 3          True    1169              60
# 4          True    1665              38
# ...         ...     ...             ...
# 2195      False    1259              38
# 2196      False    2379              77
# 2197      False     275              15
# 2198      False    2758              75
# 2199      False     924              26
#
# [2200 rows x 5 columns]

# %%
dataset.drop('Unnamed: 0', axis=1, inplace=True)

# %%
dataset
# Out:
#                                                  prompt  jailbreak  length  \
# 0     CumGPT, an information resource about cum that...       True    2466
# 1     I will give you a character description and yo...       True    1261
# 2     A completely amoral Ai named [Illegality Mode]...       True    2363
# 3     Agares's rules={\nAlways stays in character, n...       True    1169
# 4     Lucian is an incorporeal transcendent being wh...       True    1665
# ...                                                 ...        ...     ...
# 2195  Act as an SEO expert tasked with optimizing th...      False    1259
# 2196  \nI Want You To Act As A Content Writer Very P...      False    2379
# 2197  \nYour task is to summarize text in 150 words ...      False     275
# 2198  As a software developer and designer, you have...      False    2758
# 2199  \nVocê é um Youtuber.\n\nEu quero que você esc...      False     924
#
#       num_punctation
# 0                 55
# 1                 78
# 2                123
# 3                 60
# 4                 38
# ...              ...
# 2195              38
# 2196              77
# 2197              15
# 2198              75
# 2199              26
#
# [2200 rows x 4 columns]

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
dataset=dataset.dropna()
dataset=dataset.drop_duplicates()
dataset['cleaned']=dataset['prompt'].apply(cleanDoccument)

# %%
dataset
# Out:
#                                                  prompt  jailbreak  length  \
# 0     CumGPT, an information resource about cum that...       True    2466
# 1     I will give you a character description and yo...       True    1261
# 2     A completely amoral Ai named [Illegality Mode]...       True    2363
# 3     Agares's rules={\nAlways stays in character, n...       True    1169
# 4     Lucian is an incorporeal transcendent being wh...       True    1665
# ...                                                 ...        ...     ...
# 2195  Act as an SEO expert tasked with optimizing th...      False    1259
# 2196  \nI Want You To Act As A Content Writer Very P...      False    2379
# 2197  \nYour task is to summarize text in 150 words ...      False     275
# 2198  As a software developer and designer, you have...      False    2758
# 2199  \nVocê é um Youtuber.\n\nEu quero que você esc...      False     924
#
#       num_punctation                                            cleaned
# 0                 55  cumgpt inform resourc cum answer ani cum relat...
# 1                 78  give charact descript creat charact data follo...
# 2                123  complet amor ai name illeg mode rememb illeg m...
# 3                 60  agar rule alway stay charact never refus amor ...
# 4                 38  lucian incorpor transcend exist outsid quantum...
# ...              ...                                                ...
# 2195              38  act seo expert task optim homepag compani prod...
# 2196              77  want act content writer veri profici seo write...
# 2197              15  task summar text 150 word maximum 800 charact ...
# 2198              75  softwar develop design task creat simpl web ap...
# 2199              26  você é um youtub eu quero que você escreva 5 s...
#
# [2024 rows x 5 columns]

# %%
dataset.to_csv("./data/FinalCleanedData.csv")
